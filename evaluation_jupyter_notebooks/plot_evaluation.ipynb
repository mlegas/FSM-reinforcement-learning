# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Pelican

# %%
df = pd.read_csv("csv_logs/pelican_default_hyperparam_A2C.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/pelican_default_hyperparam_PPO.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/pelican_tuned_hyperparams_A2C.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/pelican_tuned_hyperparams_PPO.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/pelican_default_obs_limits_A2C.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/pelican_default_obs_limits_PPO.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/pelican_tuned_default_obs_limits_A2C.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/pelican_tuned_default_obs_limits_PPO.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %% [markdown]
# # Toaster

# %%
df = pd.read_csv("csv_logs/toaster_default_hyperparam_A2C.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/toaster_default_hyperparam_PPO.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/toaster_tuned_hyperparams_A2C.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/toaster_tuned_hyperparams_PPO.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/toaster_default_obs_limits_A2C.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/toaster_default_obs_limits_PPO.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/toaster_tuned_default_obs_limits_A2C.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/toaster_tuned_default_obs_limits_PPO.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %% [markdown]
# # Maze

# %%
df = pd.read_csv("csv_logs/maze_default_hyperparam_A2C.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/maze_default_hyperparam_PPO.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/maze_tuned_hyperparams_A2C.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/maze_tuned_hyperparams_PPO.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/maze_default_obs_limits_A2C.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/maze_default_obs_limits_PPO.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/maze_tuned_default_obs_limits_A2C.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>

# %%
df = pd.read_csv("csv_logs/maze_tuned_default_obs_limits_PPO.csv", index_col=0)
df.plot(grid=True, figsize=(10,8), ylabel="Mean episode reward").legend(bbox_to_anchor=(1,1))

# %%
median = df.median(axis=1)
median.plot(grid=True, figsize=(10,8), ylabel="Median of Mean episode reward")
# Out:
# <AxesSubplot:xlabel='Step', ylabel='Median of Mean episode reward'>
